# %% [markdown]
# # Last Year's Stats
#
# This section will be last years stats for our teams so we have something to compare this years data too.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://fbref.com/en/comps/Big5/2023-2024/2023-2024-Big-5-European-Leagues-Stats"

tables = pd.read_html(url)

# View how many tables were found
print(f"Found {len(tables)} tables.")

# Check which table is the one you're interested in
for i, table in enumerate(tables):
    print(f"Table {i}:")
    print(table.head())
# Out:
# Found 1 tables.
# Table 0:
#    Rk            Squad  Country  LgRk  MP   W  D  L  GF  GA  GD  Pts  Pts/MP  \
# 0   1       Leverkusen   de GER     1  34  28  6  0  89  24  65   90    2.65
# 1   2      Real Madrid   es ESP     1  38  29  8  1  87  26  61   95    2.50
# 2   3            Inter   it ITA     1  38  29  7  2  89  22  67   94    2.47
# 3   4  Manchester City  eng ENG     1  38  28  7  3  96  34  62   91    2.39
# 4   5          Arsenal  eng ENG     2  38  28  5  5  91  29  62   89    2.34
#
#      xG   xGA   xGD  xGD/90  Attendance        Top Team Scorer      Goalkeeper
# 0  73.6  29.9  43.7    1.29       29994   Victor Boniface - 14  Lukáš Hrádecký
# 1  68.8  35.4  33.4    0.88       72061   Jude Bellingham - 19    Andriy Lunin
# 2  78.2  31.2  47.1    1.24       72838  Lautaro Martínez - 24     Yann Sommer
# 3  80.5  35.6  44.9    1.18       53012    Erling Haaland - 27         Ederson
# 4  76.1  27.9  48.2    1.27       60236       Bukayo Saka - 16      David Raya

# %%
last_year_df = tables[0]

# %%
last_year_df = last_year_df.drop(columns="Rk")
last_year_df.head()
# Out:
#              Squad  Country  LgRk  MP   W  D  L  GF  GA  GD  Pts  Pts/MP  \
# 0       Leverkusen   de GER     1  34  28  6  0  89  24  65   90    2.65
# 1      Real Madrid   es ESP     1  38  29  8  1  87  26  61   95    2.50
# 2            Inter   it ITA     1  38  29  7  2  89  22  67   94    2.47
# 3  Manchester City  eng ENG     1  38  28  7  3  96  34  62   91    2.39
# 4          Arsenal  eng ENG     2  38  28  5  5  91  29  62   89    2.34
#
#      xG   xGA   xGD  xGD/90  Attendance        Top Team Scorer      Goalkeeper
# 0  73.6  29.9  43.7    1.29       29994   Victor Boniface - 14  Lukáš Hrádecký
# 1  68.8  35.4  33.4    0.88       72061   Jude Bellingham - 19    Andriy Lunin
# 2  78.2  31.2  47.1    1.24       72838  Lautaro Martínez - 24     Yann Sommer
# 3  80.5  35.6  44.9    1.18       53012    Erling Haaland - 27         Ederson
# 4  76.1  27.9  48.2    1.27       60236       Bukayo Saka - 16      David Raya

# %%
ly_premier_league_df = last_year_df[last_year_df["Country"] == "eng ENG"].reset_index(drop=True)
ly_premier_league_df.head()
# Out:
#              Squad  Country  LgRk  MP   W   D   L  GF  GA  GD  Pts  Pts/MP  \
# 0  Manchester City  eng ENG     1  38  28   7   3  96  34  62   91    2.39
# 1          Arsenal  eng ENG     2  38  28   5   5  91  29  62   89    2.34
# 2        Liverpool  eng ENG     3  38  24  10   4  86  41  45   82    2.16
# 3      Aston Villa  eng ENG     4  38  20   8  10  76  61  15   68    1.79
# 4        Tottenham  eng ENG     5  38  20   6  12  74  61  13   66    1.74
#
#      xG   xGA   xGD  xGD/90  Attendance      Top Team Scorer  \
# 0  80.5  35.6  44.9    1.18       53012  Erling Haaland - 27
# 1  76.1  27.9  48.2    1.27       60236     Bukayo Saka - 16
# 2  87.8  45.7  42.0    1.11       55979   Mohamed Salah - 18
# 3  63.3  59.9   3.4    0.09       41858   Ollie Watkins - 19
# 4  68.2  63.4   4.8    0.13       61482   Son Heung-min - 17
#
#           Goalkeeper
# 0            Ederson
# 1         David Raya
# 2            Alisson
# 3  Emiliano Martínez
# 4  Guglielmo Vicario

# %%
ly_premier_league_df = ly_premier_league_df[0:8]

ly_premier_league_df.shape
# Out:
# (8, 19)

# %%
ly_ligue_1_dataset = last_year_df[last_year_df["Country"] == "fr FRA"].reset_index(drop=True)

ly_ligue_1_dataset.head()
# Out:
#        Squad Country  LgRk  MP   W   D  L  GF  GA  GD  Pts  Pts/MP    xG  \
# 0  Paris S-G  fr FRA     1  34  22  10  2  81  33  48   76    2.24  68.8
# 1     Monaco  fr FRA     2  34  20   7  7  68  42  26   67    1.97  55.0
# 2      Brest  fr FRA     3  34  17  10  7  53  34  19   61    1.79  48.3
# 3      Lille  fr FRA     4  34  16  11  7  52  34  18   59    1.74  48.6
# 4       Nice  fr FRA     5  34  15  10  9  40  29  11   55    1.62  49.9
#
#     xGA   xGD  xGD/90  Attendance          Top Team Scorer  \
# 0  40.0  28.8    0.85       46834       Kylian Mbappé - 27
# 1  43.5  11.5    0.34        7884   Wissam Ben Yedder - 16
# 2  39.2   9.1    0.27       14513  Romain Del Castillo - 8
# 3  36.5  12.2    0.36       39932      Jonathan David - 19
# 4  35.5  14.4    0.42       24952         Terem Moffi - 11
#
#              Goalkeeper
# 0  Gianluigi Donnarumma
# 1          Philipp Köhn
# 2           Marco Bizot
# 3       Lucas Chevalier
# 4          Marcin Bułka

# %%
ly_ligue_1_dataset = ly_ligue_1_dataset[0:8]

ly_ligue_1_dataset.shape
# Out:
# (8, 19)
